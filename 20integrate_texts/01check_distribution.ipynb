# %%
# 種々のdatasetをintagrateします
# こちらはデータ配分の確認用です｡
# 本番ではintegrate_dataset.pyを実行します｡

# %load_ext autoreload
# %autoreload 2

# %%
from loaders.loaders import *
from loaders.RecordDistributor import RecordDistributor

# %%
from dataset_dict import dataset_dict
distributor=RecordDistributor(dataset_dict)
distributor.percent_df
# Out:
# Source         ja0        ja1        ja2        ja3        ja4   wiki(en)
# Stage
# Stage 1   7.459445  12.253162   9.084146  10.453708  22.636969  38.112571
# Stage 2  61.718568   5.068789   3.757856   4.324406   9.364279  15.766102
# Stage 3   2.241318  73.634956   2.729488   3.140996   6.801666  11.451576
# Stage 4   2.736379   4.494878  66.648961   3.834777   8.304013  13.980992
# Stage 5   2.497910   4.103160   3.041966  70.014044   7.580338  12.762582
# Stage 6   1.407169   2.311469   1.713657   1.972015  85.406035   7.189655

# %%
distributor.record_df
# Out:
# Source      ja0     ja1     ja2     ja3     ja4  wiki(en)      Sum
# Stage
# Stage 1   14940   24541   18194   20937   45338     76333   200283
# Stage 2  298816   24541   18194   20937   45338     76333   484159
# Stage 3   14940  490830   18194   20937   45338     76333   666572
# Stage 4   14940   24541  363888   20937   45338     76333   545977
# Stage 5   14940   24541   18194  418754   45338     76333   598100
# Stage 6   14940   24541   18194   20937  906761     76333  1061706

# %%
#distributor.load_datasets()

# %%
import random
from tqdm import tqdm
#distributor.write_jsonl(output_path,overwrite=conf["overwrite"])
