# %%
# 種々のdatasetをintagrateします
# こちらはデータ配分の確認用です｡
# 本番ではintegrate_dataset.pyを実行します｡

# %load_ext autoreload
# %autoreload 2
# Out:
# {'0': 13334032, '1': 10640834, '4': 5888113, '3': 15181606, '2': 5932906}
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from loaders.loaders import *
from loaders.RecordDistributor import RecordDistributor

# %%
from dataset_dict import dataset_dict
distributor=RecordDistributor(dataset_dict)
distributor.percent_df
# Out:
# Source         ja0        ja1        ja2        ja3        ja4   wiki(en)
# Stage
# Stage 1  16.638949  13.278222   7.403407  18.944457   7.347503  36.387462
# Stage 2  87.212656   3.479873   1.940238   4.964844   1.925587   0.476802
# Stage 3   5.237013  83.584937   2.330180   5.962658   2.312584   0.572628
# Stage 4   8.073368   6.442713  71.844061   9.192021   3.565075   0.882762
# Stage 5   3.911580   3.121521   1.740436  89.071469   1.727293   0.427702
# Stage 6   8.115184   6.476083   3.610806   9.239632  71.670960   0.887334

# %%
distributor.record_df
# Out:
# Source        ja0      ja1      ja2       ja3      ja4  wiki(en)       Sum
# Stage
# Stage 1    533361   425633   237316    607264   235524   1166399   3205497
# Stage 2  10667225   425633   237316    607264   235524     58319  12231281
# Stage 3    533361  8512667   237316    607264   235524     58319  10184451
# Stage 4    533361   425633  4746324    607264   235524     58319   6606425
# Stage 5    533361   425633   237316  12145284   235524     58319  13635437
# Stage 6    533361   425633   237316    607264  4710490     58319   6572383

# %%
#distributor.load_datasets()

# %%
import random
from tqdm import tqdm
#distributor.write_jsonl(output_path,overwrite=conf["overwrite"])
